# %%
import pandas as pd
import numpy as np

# %%
df_raw = pd.read_csv(r"C:\Users\yog15\Downloads\metadata.csv")

# ✅ GOLDEN RULE — Copy banao!
df = df_raw.copy()

# %%
df
# Out:
#      patient_id  lesion_id  smoke  drink background_father background_mother  \
# 0      PAT_1516       1765    NaN    NaN               NaN               NaN
# 1        PAT_46        881  False  False         POMERANIA         POMERANIA
# 2      PAT_1545       1867    NaN    NaN               NaN               NaN
# 3      PAT_1989       4061    NaN    NaN               NaN               NaN
# 4       PAT_684       1302  False   True         POMERANIA         POMERANIA
# ...         ...        ...    ...    ...               ...               ...
# 2293   PAT_1708       3156    NaN    NaN               NaN               NaN
# 2294     PAT_46        880  False  False         POMERANIA         POMERANIA
# 2295   PAT_1343       1217    NaN    NaN               NaN               NaN
# 2296    PAT_326        690  False  False         POMERANIA         POMERANIA
# 2297   PAT_1714       3189    NaN    NaN               NaN               NaN
#
# ...

# %%
print(df.shape)
# Out:
# (2298, 26)

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2298 entries, 0 to 2297
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   patient_id           2298 non-null   str
#  1   lesion_id            2298 non-null   int64
#  2   smoke                1494 non-null   object
#  3   drink                1494 non-null   object
#  4   background_father    1480 non-null   str
#  5   background_mother    1476 non-null   str
#  6   age                  2298 non-null   int64
#  7   pesticide            1494 non-null   object
#  8   gender               1494 non-null   str
#  9   skin_cancer_history  1494 non-null   object
#  10  cancer_history       1494 non-null   object
#  11  has_piped_water      1494 non-null   object
#  12  has_sewage_system    1494 non-null   object
#  13  fitspatrick          1494 non-null   float64
#  14  region               2298 non-null   str
# ...

# %%
# Sirf data types dekho- i mean datatypes check karo

print(df.dtypes)
# Out:
# patient_id                 str
# lesion_id                int64
# smoke                   object
# drink                   object
# background_father          str
# background_mother          str
# age                      int64
# pesticide               object
# gender                     str
# skin_cancer_history     object
# cancer_history          object
# has_piped_water         object
# has_sewage_system       object
# fitspatrick            float64
# region                     str
# diameter_1             float64
# diameter_2             float64
# diagnostic                 str
# itch                       str
# grew                       str
# hurt                       str
# changed                    str
# bleed                      str
# elevation                  str
# img_id                     str
# biopsed                   bool
# dtype: object

# %%
print(df.head(10))
# Out:
#   patient_id  lesion_id  smoke  drink background_father background_mother  \
# 0   PAT_1516       1765    NaN    NaN               NaN               NaN
# 1     PAT_46        881  False  False         POMERANIA         POMERANIA
# 2   PAT_1545       1867    NaN    NaN               NaN               NaN
# 3   PAT_1989       4061    NaN    NaN               NaN               NaN
# 4    PAT_684       1302  False   True         POMERANIA         POMERANIA
# 5   PAT_1549       1882    NaN    NaN               NaN               NaN
# 6    PAT_778       1471  False   True           GERMANY             ITALY
# 7    PAT_117        179  False  False         POMERANIA         POMERANIA
# 8   PAT_1995       4080    NaN    NaN               NaN               NaN
# 9    PAT_705       4015  False   True           GERMANY           GERMANY
#
#    age pesticide  gender skin_cancer_history  ... diameter_2 diagnostic  \
# 0    8       NaN     NaN                 NaN  ...        NaN        NEV
# ...

# %%
print(df.tail(10))
# Out:
#      patient_id  lesion_id  smoke  drink background_father background_mother  \
# 2288   PAT_1407       1402    NaN    NaN               NaN               NaN
# 2289    PAT_386        785   True  False         POMERANIA         POMERANIA
# 2290   PAT_1294       1031    NaN    NaN               NaN               NaN
# 2291    PAT_273        421  False  False         POMERANIA         POMERANIA
# 2292    PAT_491        934  False  False         POMERANIA         POMERANIA
# 2293   PAT_1708       3156    NaN    NaN               NaN               NaN
# 2294     PAT_46        880  False  False         POMERANIA         POMERANIA
# 2295   PAT_1343       1217    NaN    NaN               NaN               NaN
# 2296    PAT_326        690  False  False         POMERANIA         POMERANIA
# 2297   PAT_1714       3189    NaN    NaN               NaN               NaN
#
#       age pesticide  gender skin_cancer_history  ... diameter_2 diagnostic  \
# ...

# %%
# Random n rows dekho — surprise!
# Real data feel milta hai!
print(df.sample(10))
# Out:
#      patient_id  lesion_id  smoke  drink background_father background_mother  \
# 1109    PAT_928       1764  False  False         POMERANIA         POMERANIA
# 1403     PAT_99        153  False  False         POMERANIA         POMERANIA
# 2233   PAT_1967       3976    NaN    NaN               NaN               NaN
# 969     PAT_409       2614  False  False             ITALY             ITALY
# 1158   PAT_1486       1684    NaN    NaN               NaN               NaN
# 536     PAT_822       1550  False  False               UNK               UNK
# 335     PAT_522        986  False  False             ITALY             ITALY
# 643     PAT_412        817  False  False         POMERANIA         POMERANIA
# 1301   PAT_1946       3924    NaN    NaN               NaN               NaN
# 653    PAT_2106       4590    NaN    NaN               NaN               NaN
#
#       age pesticide  gender skin_cancer_history  ... diameter_2 diagnostic  \
# ...

# %%
print(df.isna().sum())
# Out:
# patient_id               0
# lesion_id                0
# smoke                  804
# drink                  804
# background_father      818
# background_mother      822
# age                      0
# pesticide              804
# gender                 804
# skin_cancer_history    804
# cancer_history         804
# has_piped_water        804
# has_sewage_system      804
# fitspatrick            804
# region                   0
# diameter_1             804
# diameter_2             804
# diagnostic               0
# itch                     0
# grew                     0
# hurt                     0
# changed                  0
# bleed                    0
# elevation                0
# img_id                   0
# biopsed                  0
# dtype: int64

# %%
print(len(df))
print(df['smoke'].isna().sum())

print(df['drink'].isna().sum())
# Out:
# 2298
# 804
# 804

# %%
# yeh check kar raha hu ki in dono columns mei koi messy data toh nahi hai na.

print(df['biopsed'].unique())
print()
print(df['diagnostic'].unique())
# Out:
# [False  True]
#
# <StringArray>
# ['NEV', 'BCC', 'ACK', 'SEK', 'SCC', 'MEL']
# Length: 6, dtype: str

# %% [raw]
# 🎯 Most Important Columns!
#
# Column                               Matlab
# diagnostic                        Doctors ka final diagnosis — yeh hai target variable!
# biopsed                           Kya biopsy ki gayi? (microscope se tissue check karna) ✅/❌
#
#
#
# matlab biopsy ke baad hi pata chalta hai kya cancer hai ya nahi , aur agar cancer hai toh kaunse 6 types mei se hai.
#
#
#
# Agar biopsy ke baad hi pata chalta hai cancer hai ya nahi aur kaunsa type hai...
# toh jo patients biopsed = False hain, unka diagnostic column mein kya values aani chahiye thi logically? 🤔
#
# Aur agar unka diagnostic value hai bhi dataset mein — toh wo data reliable hai ya unreliable?
# Yeh ek bahut important Data Quality question hai jo har Data Analyst ko poochna chahiye! 💪

# %%
print(df[df['biopsed']==False]['diagnostic'].value_counts())
print()
print(df[df['biopsed']==True]['diagnostic'].value_counts())
# Out:
# diagnostic
# ACK    552
# SEK    220
# NEV    184
# Name: count, dtype: int64
#
# diagnostic
# BCC    845
# SCC    192
# ACK    178
# NEV     60
# MEL     52
# SEK     15
# Name: count, dtype: int64

# %% [markdown]
# 🔑 Seedhi Baat
# Biopsed = False wale 956 patients mein:
#
# Sirf NEV, ACK, SEK hain
# BCC, SCC, MEL — ek bhi nahi!
#
# Biopsed = True wale 1342 patients mein:
#
# BCC, SCC, MEL sab hain
# Yani cancer sirf biopsy ke baad confirm hota hai
#
# Key observation: Biopsed=False mein BCC, SCC, MEL ZERO hain. Sirf biopsed=True mein cancer confirm hota hai!

# %% [markdown]
# 🤔 Ab Tumse Ek Sawaal
# Tumne khud bola tha — "biopsy ke baad hi pata chalta hai cancer hai ya nahi"
# Toh socho — ACK diagnosis biopsed=False mein bhi hai aur biopsed=True mein bhi hai.
# ACK matlab hai Actinic Keratosis — jo ek pre-cancerous condition hai.
# Yeh kaise possible hai ki bina biopsy ke bhi ACK diagnose hua?
# Real life mein doctor kaise bina biopsy ke kuch conditions identify kar leta hai? 🤔
# Yeh samjho toh data cleaning ka ek important decision clear ho jaayega! 💪

# %% [markdown]
# Bilkul! Main tumhe sochna sikhata hoon. 🧠
# Real life se socho — doctor ke paas jao jab skin pe kuch ajeeb dikhta hai...
#
# Doctor Ka Process Socho
# Pehla step — Doctor tumhari skin dekhta hai, touch karta hai, texture check karta hai. Bina kisi test ke!
# Dusra step — Agar usse lagta hai yeh serious hai, tab biopsy karta hai.
# Teesra step — Biopsy se confirm hota hai ki exactly kaunsa cancer hai.
#
#
# Toh ACK Kaise Bina Biopsy?
# Actinic Keratosis ki skin pe bahut specific signs hote hain jo experienced doctor aankhon se pehchaan leta hai:
#
# Rough, scaly patch
# Specific color
# Specific texture
#
# Toh doctor visually diagnose kar deta hai — biopsy ki zarurat nahi!
#
#
# 🎯 Ab Data Analyst Ki Tarah Socho
# Dataset mein yeh columns hain jo doctor ki aankhon ki jagah kaam karte hain:
# itch, grew, hurt, changed, bleed, elevation, diameter_1, diameter_2
# Tumse sawaal — sirf ek minute socho:
#
# Agar kisi patient ka grew = True, changed = True, aur bleed = True hai...
# toh kya us patient ko biopsy ki zyada zarurat hai ya kam?
#
# Jawab do — phir main tumhe batata hoon yeh data cleaning se kaise connect hota hai! 💪
#
#
# my answer was : kam zaroorat hai kyunki aankhon se dikh raha hai might be usse skin cancer hai.
#
#
# kam zaroorat hai kyunki aankhon se dikh raha hai might be usse skin cancer hai.
#
# May 25
# Ruko ruko! 🛑
#
# Tumne ulta socha — aur yeh bilkul normal hai, beginners mein yeh common mistake hoti hai!
#
# Seedha Socho — Real Life Example
# Tumhare haath pe ek daag hai.
#
# Case 1: Daag same hai, koi change nahi, khujli nahi, khoon nahi.
#
# Case 2: Daag bada ho raha hai, rang badal raha hai, khoon aa raha hai!
#
# Kaunse case mein tum turant doctor ke paas jaoge? 🤔
#
# Obviously Case 2!
#
# Toh doctor bhi Case 2 mein zyada seriously lega aur bolega —
#
# "Yeh sirf dekhne se confirm nahi hoga, humein andar se tissue check karna padega"
#
# Yahi hai BIOPSY!

# %% [raw]
# Toh Seedha Rule Yeh Hai
#
# grew=True, changed=True, bleed=True
#         ⬇️
# Danger signs zyada hain
#         ⬇️
# Doctor zyada worried hai
#         ⬇️
# Biopsy ki ZYADA zarurat hai
#
# mujhe lagta hai jinka yeh saare columns true hai unko biopsy karna bohot zaroori hai . woh high risk cancer pe ho sakte hai.
#
#
# Toh Rule Yeh Bana  -- yeh tujhe aur clear kar dega.
# Sirf aankhon se dikh sakta hai:
# NEV, SEK, ACK
#         ⬇️
# Biopsy zaruri nahi
#         ⬇️
# Biopsed = False possible
#
# Confirm karna padega:
# BCC, SCC, MEL
#         ⬇️
# Biopsy ZARURI hai
#         ⬇️
# Sirf Biopsed = True mein milenge
#
#
#
#
# 🎯 Ab Data Cleaning Ka Connection
# Yeh samjho — dataset mein jo patients biopsed = False hain, unke symptoms kaisa hoga generally?
# Mild ya severe? 🤔
# Yeh socho aur jawab do — ek aur important data cleaning decision khulega! 💪
#
# my answer was: mild joki right hai.

# %%
# Ab Verify Karte Hain Tumhari Thinking Ko. jo maine mild answer diya hu
# Biopsed=False wale patients ke symptoms

print("Biopsed = FALSE wale symptoms:")
print(df[df['biopsed']==False][['itch','grew','hurt','changed','bleed','elevation']].value_counts().head(5))

print()

# Biopsed=True wale patients ke symptoms  
print("Biopsed = TRUE wale symptoms:")
print(df[df['biopsed']==True][['itch','grew','hurt','changed','bleed','elevation']].value_counts().head(5))
# Out:
# Biopsed = FALSE wale symptoms:
# itch   grew   hurt   changed  bleed  elevation
# TRUE   FALSE  FALSE  FALSE    FALSE  FALSE        275
# FALSE  TRUE   FALSE  FALSE    FALSE  TRUE         151
#        FALSE  FALSE  FALSE    FALSE  FALSE        126
#                                      TRUE         109
# TRUE   FALSE  FALSE  FALSE    FALSE  TRUE          76
# Name: count, dtype: int64
#
# Biopsed = TRUE wale symptoms:
# itch   grew  hurt   changed  bleed  elevation
# TRUE   TRUE  TRUE   FALSE    TRUE   TRUE         131
#        UNK   FALSE  UNK      FALSE  TRUE          95
#        TRUE  FALSE  FALSE    TRUE   TRUE          87
# FALSE  UNK   FALSE  UNK      FALSE  TRUE          82
# TRUE   TRUE  FALSE  FALSE    FALSE  TRUE          82
# Name: count, dtype: int64

# %% [raw]
# Strategy Pehle, Code Baad Mein!
# Ek Data Analyst kabhi bhi randomly columns fill nahi karta.
# Pehle har column ka nature samajhta hai, phir decide karta hai strategy.
#
# Columns Ko Groups Mein Socho
# Dataset ke saare missing columns ko 3 buckets mein daalo:
# Bucket 1 — Numbers 🔢
# diameter_1, diameter_2
#
# Bucket 2 — Haan/Nahi wale ✅❌
# smoke, drink, pesticide, skin_cancer_history, cancer_history, has_piped_water, has_sewage_system
#
# Bucket 3 — Categories 🏷️
# gender, fitspatrick, background_father, background_mother

# %% [raw]
# Har bucket ke liye apne dimag se socho:
#
# Agar missing hai toh kya fill karna logical hoga? Aur kyun?
#
# Bucket 2 ke baare mein socho — smoke missing hai kisi ka.
# Kya hum True fill kar sakte hain? Kya hum False fill kar sakte hain? Ya kuch aur karna chahiye? 🤔
#
#
# Simple Example Se Socho
# Ek patient hai jiska:
#
# diagnostic = MEL (Melanoma — worst cancer)
# smoke = missing
#
# Tumhari soch: "Cancer hai toh smoke = True kar do"
# Lekin real life mein — kya yeh patient actually smoker tha? Tumhe pata hai? Nahi pata!
# Ho sakta hai woh patient:
#
# Kabhi cigarette nahi peeta tha 🚭
# Vegetarian tha, healthy life jeeta tha
# Sirf genetics ki wajah se cancer hua
#
# Agar tum True fill karo — toh tumne ek jhootha data point create kar diya!
#
# Iska Anjaam Kya Hoga?
#
# Galat data fill kiya
#       ⬇️
# Model galat pattern seekhega
#       ⬇️
# "Smokers ko cancer hota hai" — WRONG conclusion
#       ⬇️
# Real patients ko galat prediction milegi
#       ⬇️
# Kisi ki jaan khatre mein! ⚠️
#
# 🎯 Golden Rule Yaad Karo
#
# "Jo data hai nahi, usse ASSUME mat karo. Jo pata nahi, woh UNKNOWN rehne do."
#
#
# Toh Bucket 2 Ka Sahi Answer Kya Hai?
# smoke, drink, pesticide, skin_cancer_history, cancer_history — sab missing hain biopsed=False mein.
# Humein pata nahi hai ki woh:
#
# True the
# False the
#
# Toh kya fill karna chahiye? 🤔
# Ek word mein jawab do! 💪

# %% [raw]
# `smoke`, `drink`, `pesticide`, `skin_cancer_history`, `cancer_history   -- sab column mei false aayega i think
# kyunki `biopsed=False  hai in columns ka matlab Mild symptoms = Doctor ne serious nahi samjha.
#
# columns ka matlab Mild symptoms = Doctor ne serious nahi samjha.
#
# May 25
# Achha socha! Lekin abhi bhi ek confusion hai. 🤔
#
# Main ek aur real life example deta hoon —
#
# Socho Ek Patient Ki Story
# Ramu kaka, age 65, Mumbai:
#
# Haath pe ek chota sa daag hai
# Daag badha nahi, khujli nahi, khoon nahi
# Doctor ne dekha — mild symptoms — biopsy nahi ki
# Diagnostic = NEV (normal mole)
# Lekin Ramu kaka ki personal life:
#
# 40 saal se bidi peete hain 🚬
# Roz daaru peete hain 🍺
# Khet mein pesticide use karte hain 🌾
#
#
# Sawaal Yeh Hai —
# Ramu kaka ke symptoms mild hain...
# Lekin kya unki lifestyle bhi mild hai? 🤔
# Kya smoke = False sahi hoga unke liye?
#
# Yahi Problem Hai Tumhari Thinking Mein
# Tum do alag cheezein mix kar rahe ho:
# Cheez                   Matlab
# Symptoms               Daag kaisa dikhta hai
# Lifestyle             Patient kaisi zindagi jeeta hai
#
# Yeh dono independent hain ek doosre se! Ek ka doosre pe koi direct connection nahi!
#
#
# 🎯 Toh Sahi Answer Kya Hai?
# Missing smoke, drink, pesticide ke liye —
# Humein sachchi mein nahi pata ki woh True the ya False.
# Toh Data Science mein iske liye ek special value hoti hai fill karne ke liye —
# Ek word mein socho — woh kya hogi? 🤔
# Hint: Na True, na False... balki... 💪
#
# May 25Claude responded: BILKUL SAHI!BILKUL SAHI! 🎯🔥
# NaN — Not a Number — matlab UNKNOWN!
# Yahi sahi jawab hai!

# %% [raw]
# Toh Bucket 2 Ka Final Decision
#
# smoke, drink, pesticide,
# skin_cancer_history, cancer_history,
# has_piped_water, has_sewage_system
#           ⬇️
# Hume sachchi mein nahi pata
#           ⬇️
# NaN rehne do — mat chedo!

# %% [raw]
# 🎯 Ab Tumse Ek Sawaal
# Yeh sab samajhne ke baad —
# Dataset mein ACK dono jagah hai — biopsed=False mein bhi, biopsed=True mein bhi.
# Toh kya matlab hai jab ACK biopsed=True mein hai?
# Real life mein doctor ne ACK ka biopsy kyun kiya hoga? 🤔
# Socho aur jawab do! 💪
#
#
# my answer: kyunki diameter_1 aur diameter _2 ka size bada hoda , bleed = true hoga, elevation= true hoga .
#
#
# elevation= true hoga .
#
# May 25
# BILKUL SAHI! 🔥🎯
#
# Ekdum perfect thinking! Tum Data Analyst ki tarah sochne lage ho!
#
# Tumne Jo Socha — Woh Exactly Sahi Hai
#
# ACK patient aaya
#       ⬇️
# Doctor ne dekha:
# - Size bada hai ⚠️
# - Bleeding ho rahi hai ⚠️
# - Elevated (utha hua) hai ⚠️
#       ⬇️
# Doctor ne socha:
# "Yeh sirf pre-cancer nahi lag raha
#  Kuch aur bhi ho sakta hai andar"
#       ⬇️
# Biopsy kar do — confirm karte hain!
#       ⬇️
# Biopsed = True

# %%
print(df[['diameter_1', 'diameter_2']].describe())
print()
print(df[['diameter_1', 'diameter_2']].corr())
# Out:
#         diameter_1   diameter_2
# count  1494.000000  1494.000000
# mean     11.897055     8.852209
# std       8.634492     5.797036
# min       0.000000     0.000000
# 25%       7.000000     5.000000
# 50%      10.000000     8.000000
# 75%      15.000000    10.000000
# max     100.000000    70.000000
#
#             diameter_1  diameter_2
# diameter_1    1.000000    0.858215
# diameter_2    0.858215    1.000000

# %%
overall = df['diameter_1'].mean()
false_mean = df[df['biopsed']==False]['diameter_1'].mean()
true_mean = df[df['biopsed']==True]['diameter_1'].mean()

print(f"Overall average: {overall:.2f}")
print(f"Biopsed=False average: {false_mean:.2f}")
print(f"Biopsed=True average: {true_mean:.2f}")
# Out:
# Overall average: 11.90
# Biopsed=False average: 10.40
# Biopsed=True average: 12.07

# %%
ack_false = df[(df['biopsed']==False) & (df['diagnostic']=='ACK')]   # 552 rows * 26 columns
ack_true  = df[(df['biopsed']==True)  & (df['diagnostic']=='ACK')]   # 178 rows * 26 columns

#print(ack_false)
#print(f"_______________________________")
#print(ack_true)
#print(f"_______________________________")


print("ACK + Biopsed=False ka average size:")
print(ack_false[['diameter_1','diameter_2']].mean())

print()
print("ACK + Biopsed=True ka average size:")
print(ack_true[['diameter_1','diameter_2']].mean())

print()
print("ACK + Biopsed=False mein bleed=True kitne?")
print(ack_false['bleed'].value_counts())

print()
print("ACK + Biopsed=True mein bleed=True kitne?")
print(ack_true['bleed'].value_counts())
# Out:
# ACK + Biopsed=False ka average size:
# diameter_1    10.828571
# diameter_2     7.580952
# dtype: float64
#
# ACK + Biopsed=True ka average size:
# diameter_1    11.067416
# diameter_2     8.544944
# dtype: float64
#
# ACK + Biopsed=False mein bleed=True kitne?
# bleed
# FALSE    500
# TRUE      52
# Name: count, dtype: int64
#
# ACK + Biopsed=True mein bleed=True kitne?
# bleed
# FALSE    141
# TRUE      37
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2298 entries, 0 to 2297
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   patient_id           2298 non-null   str
#  1   lesion_id            2298 non-null   int64
#  2   smoke                1494 non-null   object
#  3   drink                1494 non-null   object
#  4   background_father    1480 non-null   str
#  5   background_mother    1476 non-null   str
#  6   age                  2298 non-null   int64
#  7   pesticide            1494 non-null   object
#  8   gender               1494 non-null   str
#  9   skin_cancer_history  1494 non-null   object
#  10  cancer_history       1494 non-null   object
#  11  has_piped_water      1494 non-null   object
#  12  has_sewage_system    1494 non-null   object
#  13  fitspatrick          1494 non-null   float64
#  14  region               2298 non-null   str
# ...

# %% [raw]
# `smoke`, `drink`, `pesticide`, `skin_cancer_history`, `cancer_history` — sab missing hain biopsed=False mein- yeh aapne kaha hai.
# ek best data analyst banne ke liye sabse pehle apne data set ko samajhna bohot zaroori hai. columns ka nature.
#  mujhe yeh lag raha hai mere dataset mei biopsed column ki value agar True hai toh uske saare rows mei data hai.
#  Aur agar  biopsed column ki value agar FALSE hai toh uske rows saare filled bhi ho sakte hai ya phir
#  partially filled bhi ho sakte hai . kya mei sahi hu ya phir galat.

# %%
print("=== Biopsed=TRUE mein missing values ===")
true_df = df[df['biopsed']==True]
print(true_df)    # 1342 rows * 26 columns
print('__________________________________________')
print(true_df.isnull().sum())

print('*********************************************')

print()
print("=== Biopsed=FALSE mein missing values ===")
false_df = df[df['biopsed']==False]
print(false_df)    # 956 rows * 26 columns
print('__________________________________________')
print(false_df.isnull().sum())
# Out:
# === Biopsed=TRUE mein missing values ===
#      patient_id  lesion_id  smoke  drink background_father background_mother  \
# 1        PAT_46        881  False  False         POMERANIA         POMERANIA
# 4       PAT_684       1302  False   True         POMERANIA         POMERANIA
# 6       PAT_778       1471  False   True           GERMANY             ITALY
# 7       PAT_117        179  False  False         POMERANIA         POMERANIA
# 11      PAT_967       1827  False  False         POMERANIA         POMERANIA
# ...         ...        ...    ...    ...               ...               ...
# 2289    PAT_386        785   True  False         POMERANIA         POMERANIA
# 2291    PAT_273        421  False  False         POMERANIA         POMERANIA
# 2292    PAT_491        934  False  False         POMERANIA         POMERANIA
# 2294     PAT_46        880  False  False         POMERANIA         POMERANIA
# 2296    PAT_326        690  False  False         POMERANIA         POMERANIA
#
# ...

# %% [raw]
# Kyun Yeh Important Hai?
# Tumne jo socha — uske 2 possible cases hain:
#
# Case 1 — Tumhari soch sahi nikli:
# Biopsed=True  → saara data filled ✅
# Biopsed=False → partially filled ⚠️
# Toh strategy hogi — sirf False wale rows pe focus karo cleaning ke liye!
#
# Case 2 — Mixed nikla:
# Biopsed=True  → kuch missing bhi hai
# Biopsed=False → zyada missing hai
# Toh strategy alag hogi!
#
# Data analyst kabhi assume nahi karta — data ko bolne deta hai! 🎯

# %% [raw]
# Ab Ek Aur Gehri Soch
# Tumne kaha — biopsed=False mein partially filled hai.
# Matlab kuch rows mein data hai, kuch mein nahi.
# Toh ek sawaal socho:
# Jo biopsed=False wale patients hain — jinke rows partially filled hain — matlab kuch columns mein data hai...
#
# Woh data kahan se aaya? Doctor ne kya kiya hoga un patients ke saath?
#
# Ek simple real life example socho —
# Patient A — biopsed=False, smoke=FALSE, drink=FALSE, diameter_1=8
# Patient B — biopsed=False, smoke=NaN, drink=NaN, diameter_1=NaN
# Dono ka biopsed=False hai — lekin ek ka data hai, doosre ka nahi!
# Kyun aisa hoga real life mein? 🤔
# Socho aur jawab do — phir hum cleaning strategy finalize karte hain! 💪
#
#
# Do Alag Hospitals Ki Story
# Hospital A — Bada city hospital, Mumbai:
#
# Patient aaya
# Doctor ne poora form bhara — age, smoke, drink, lifestyle sab
# Lesion dekha — mild tha
# Biopsy nahi ki
# Result: biopsed=False, lekin saara data filled ✅
#
# Hospital B — Chota gaon ka clinic:
#
# Patient aaya
# Doctor ne sirf lesion dekha
# Koi form nahi bhara
# Biopsy nahi ki
# Result: biopsed=False, aur data bhi missing ⚠️
#
# Matlab Yeh Nikla
# Partially filled hone ki wajah:
# - Alag alag hospitals
# - Alag alag doctors
# - Alag alag form filling practices
# Yeh real world data ki sabse badi problem hai — inconsistency!

# %% [raw]
# # 🎯 Ab Tumhara Kaam
# #Abhi tak jo seekha — usse use karke diameter_1 aur diameter_2 fill karo!
# #Tumhe code ka hint pehle diya tha — yaad hai?
#
# biopsed_false_mask = df['biopsed'] == False
#
# # diameter_1 fill karo
# false_d1_mean = df[____]['diameter_1'].____()
# df.loc[____ & df['diameter_1'].____(), 'diameter_1'] = ____

# %%
biopsed_false_mask = df['biopsed'] == False

# diameter_1 fill karo
false_d1_mean = df[biopsed_false_mask]['diameter_1'].mean()

df.loc[
    biopsed_false_mask & df['diameter_1'].isnull(),
    'diameter_1'
] = false_d1_mean


biopsed_false_mask = df['biopsed'] == False

# diameter_2 fill karo
false_d2_mean = df[biopsed_false_mask]['diameter_2'].mean()

df.loc[
    biopsed_false_mask & df['diameter_2'].isnull(),
    'diameter_2'
] = false_d2_mean

# %%
print(df[biopsed_false_mask]['diameter_1'].isnull().sum())
print(df[biopsed_false_mask]['diameter_2'].isnull().sum())
# Out:
# 0
# 0

# %% [raw]
# Tumne khud pehle kaha tha:
#
# "smoke, drink, pesticide — NaN rehne do, assume nahi kar sakte!"
#
# Aur tumne bilkul sahi kaha tha! 💯
#
# Toh Ab NaN Fill Kyun Karna Hai? 🤔
# Kya tumhare cousin ne task mein specifically kaha hai ki lifestyle columns fill karo?
# Ya tumhe lag raha hai ki saare missing values fill karne chahiye?
# Yeh do alag cheezein hain —
# Data Analyst ka rule:
# Missing data fill karna = ALWAYS sahi nahi hota
# NaN rehna = bhi ek valid decision hai!
#
#
# Real Industry Mein Yahan 2 Options Hote Hain
# Option A — NaN wali poori row delete kardo
# python# Jo bhi row mein missing hai — hatao
# df.dropna(subset=['smoke','drink','pesticide'])
#
# Option B — NaN ko ek alag category banao
# python# Na True, na False — balki "Unknown"
# df['smoke'].fillna('Unknown')
#
# Tumse Sawaal
# Tumhare paas 2298 rows hain.
# Agar NaN wali rows delete kar do — toh bahut saara data chala jaayega.
# Task 2 mein cancer risk predict karna hai — toh zyada data achha hai ya kam? 🤔
# Yeh socho aur batao — Option A sahi hai ya Option B? Aur kyun? 💪
#
# answer: option B is right

# %% [raw]
# # smoke ka example
# df['smoke'] = df['smoke'].fillna('Unknown')
#
# df[['drink', 'pesticide']] = df[['drink', 'pesticide']] (Ye dono columns ka mini-dataframe return karta hai.).fillna('Unknown')

# %%
# df['smoke'] = df['smoke'].fillna('Unknown')

cols = ['smoke' , 'drink', 'pesticide' , 'skin_cancer_history' , 'cancer_history', 'has_piped_water', 'has_sewage_system']

df[cols] = df[cols].fillna('Unknown')

# %%
print(df['smoke'].isnull().sum())
print(df['pesticide'].isnull().sum())
# Out:
# 0
# 0

# %% [raw]
# `gender`, `fitspatrick`, `background_father`, `background_mother -- `Inhe bhi Unknown fill karna sahi hoga, kyunki
# hum sach mei nahi pata inka data, assume nahi kar sakte. lekin fitspatrick numerical column hai.

# %%
cols_1 = ['gender' , 'background_father', 'background_mother']

df[cols_1] = df[cols_1].fillna('Unknown')

# %%
fitspatrick_false_mask = df['biopsed'] == False

false_fitspatrick_mean = df[fitspatrick_false_mask]['fitspatrick'].mean()

df.loc[
    fitspatrick_false_mask & df['fitspatrick'].isnull(),
    'fitspatrick'
] = false_fitspatrick_mean

# %%
print(df['fitspatrick'].isnull().sum())
# Out:
# 0

# %%
# Ab Ek Verification Karo
#Poora cleaning verify karte hain — yeh run karo:

print("=== Remaining NaN counts ===")
print(df.isnull().sum())
# Out:
# === Remaining NaN counts ===
# patient_id             0
# lesion_id              0
# smoke                  0
# drink                  0
# background_father      0
# background_mother      0
# age                    0
# pesticide              0
# gender                 0
# skin_cancer_history    0
# cancer_history         0
# has_piped_water        0
# has_sewage_system      0
# fitspatrick            0
# region                 0
# diameter_1             0
# diameter_2             0
# diagnostic             0
# itch                   0
# grew                   0
# hurt                   0
# changed                0
# bleed                  0
# elevation              0
# img_id                 0
# biopsed                0
# dtype: int64

# %% [raw]
# WAAH! 🎯🎉🔥
# TASK 1 COMPLETE! DATA CLEANING DONE!
# Har ek column — 0 missing values!
# Tumne khud kiya — main sirf hint deta raha! 💪
#
# Abhi Tak Ka Safar — Ek Nazar Mein
#
# Kya Kiya                                  Kaise Kiya
#
# diameter_1, diameter_2                    Group-wise mean — biopsed=False ka alag mean
# smoke, drink, pesticide                     Unknown fill kiya
# skin_cancer_history, cancer_history            Unknown fill kiya
# has_piped_water, has_sewage_system                 Unknown fill kiya
# gender, background_father, background_mother           Unknown fill kiya
# fitspatrick                                           biopsed=False mask se mean fill kiya

# %%
# Ek Zaroori Kaam Ab Karo!
# Clean dataset save karo — taaki baar baar cleaning na karni pade!   Desktop pe save hua hai.

df.to_csv('metadata_cleaned.csv', index=False)
print("Saved!")
# Out:
# Saved!

# %% [raw]
# Ab Task 2 Ki Taraf! 🎯
# Cousin ka task tha:
#
# "Multiple skin cancer — logically check karo — kisko future mein cancer ho sakta hai — high risk mein kaun hai?"
#
# Toh socho — ek Data Analyst ki tarah —
# Dataset mein kaunse kaunse columns milke batayenge ki koi patient high risk mein hai? 🤔
# Apne dimag se 4-5 columns ke naam batao jo tumhe lagta hai cancer risk se related hain! 💪
#
#
# mera Final Risk Column List:
# Column                       Kyun Important
#
# grew                          Lesion bada ho raha hai — danger sign
# changed                        Rang ya shape badla — warning
# bleed                           Khoon aaya — serious sign
# hurt                            Dard hai — inflammation
# elevation                        Utha hua lesion — suspicious
# diameter_1, diameter_2           Size bada — zyada risk
# smoke                                Habit — cancer risk badhata hai
# cancer_history                     Pehle cancer — dobara chance
#
#
#
# Ab has_sewage_system Ka Jawab Bhi Do! 😊
#
# maine ulta hi soch liya tha.
# nahi . agar sewage system hai toh koi aur bhi disease ya koi aur cancer ho sakta hai. agar sewage
# system nahi toh phir ghar mei Ganda paani aayega hi nahi toh koi bimaar hi nahi padega.
#
#
# Seedha Socho —
# Agar sewage system NAHI hai ghar mein:
# Ganda paani → Ghar ke aas paas ✅
# Gandagi → Bahar ✅
# Mosquito, bacteria → Zyada ✅
# Skin infections → Zyada ✅
#
# Agar sewage system HAI:
# Saaf paani → Clean environment ✅
# Gandagi properly dispose → ✅
# Skin healthy rehne ka chance zyada ✅
#
# Lekin Tumhara Point Bhi Sahi Hai! 🎯
# Tumne kaha — "sewage se aur diseases ho sakti hain"
# Yeh bilkul sahi hai — lekin woh diseases hain:
#
# Cholera, typhoid — internal diseases
# Skin infections — bacterial
#
#
# Lekin skin cancer specifically —
#
# Sewage system se directly skin cancer ka connection bahut weak hai!
#
#
# Toh Final Decision
# has_sewage_system — Risk Score mein mat lo! ✅
# Tumhara instinct sahi tha — bas reasoning thodi adjust hui! 😊

# %% [raw]
# Ab Risk Score Banate Hain! 🎯
# Socho — tumhare paas yeh columns hain:
# grew, changed, bleed, hurt, elevation → True/False
# smoke, cancer_history → True/False/Unknown
# diameter_1, diameter_2 → Numbers
#
#
# Ek simple logic socho —
#
# Agar kisi patient ka grew=True, bleed=True, changed=True hai —
# toh uska risk zyada hai ya kam?
#
# Aur agar sab False hain — toh? 🤔
# Yeh socho — Risk Score kaise calculate karein number mein? 💪
#
# `grew=True`, `bleed=True`, `changed=True` hai — toh uska risk zyada hai.
# Aur agar sab False hain — toh risk kam hai.
#
#
# Aur agar sab False hain — toh risk kam hai.
#
# 7:36 PM
# BILKUL SAHI! 🎯
#
# Ab isko number mein convert karte hain!
#
# Simple Logic Socho
#
# grew = True  → 1 point
# grew = False → 0 point
#
# bleed = True  → 1 point
# bleed = False → 0 point
#
# changed = True  → 1 point
# changed = False → 0 point
#
#
# Matlab — jitne zyada True, utna zyada risk score!

# %% [raw]
# mujhe ek doubt hai yeh jo risk score calculate kar rahe hai hum abhi , biopsed = True and False dono values ke liye kar rahe hai kya?
#
# Socho Khud — Logic Kya Kehta Hai?
# Tumhara task hai:
#
# "Future mein kisko cancer ho sakta hai — high risk mein kaun hai?"
#
# Ab dono cases socho —
# Case 1 — Biopsed = True:
# Biopsy ho chuki hai
# Doctor ne confirm kar diya
# Cancer hai ya nahi — PATA HAI already!
#
# Case 2 — Biopsed = False:
# Biopsy nahi hui
# Cancer confirm nahi hua
# Future mein ho sakta hai — UNKNOWN!
#
# Toh Sawaal Yeh Hai 🤔
#
# Hum future risk predict karna chahte hain —
# toh jinko already pata hai unpe risk score lagana sahi hai?
# Ya sirf jinko abhi tak pata nahi unpe focus karna chahiye?
#
# Khud socho — kaunse patients pe risk score calculate karna zyada meaningful hoga? 💪

# %%
df['diameter_1'].min()
df['diameter_1'].max()

print(f"----------------------------")

df['diameter_2'].min()
df['diameter_2'].max()
# Out:
# ----------------------------
# np.float64(70.0)

# %% [raw]
# Decision 1 — Confirmed! ✅
#  Sirf biopsed=False wale patients pe risk score
# risk_df = df[df['biopsed'] == False]
# Kyunki inhe abhi tak pata nahi — yahi hamare target patients hain!
#
# Decision 2 — Smoke = Unknown
# Socho —
#
# Agar kisi ka smoking status pata hi nahi —
# toh kya hum confidently bol sakte hain woh safe hai?
#
# Nahi! Unknown matlab —
# Ho sakta hai smoke karta ho → Risk hai
# Ho sakta hai nahi karta → Risk nahi
# Toh Unknown ko hum 0.5 points denge — matlab:
#
# True    = 1 point  (confirmed risk)
# Unknown = 0.5 point (maybe risk)
# False   = 0 point  (no risk)
# Yeh sahi lagta hai tumhe? ✅
#
# Decision 3 — Diameter Ka Score
# Tumne kaha pata nahi — toh main hint deta hoon!
# Socho —
# Patient A — diameter_1 = 5mm  (chota)
# Patient B — diameter_1 = 25mm (bada)
# Kaunka risk zyada hai? Patient B!
#
# Toh diameter ko directly number ki tarah use kar sakte hain —
# Lekin ek problem hai —
# grew    = 0 ya 1        (small number)
# diameter_1 = 5 to 100  (bada number)
# Agar directly add karein toh diameter poore score pe dominate kar lega!
# Toh kya karein? 🤔
# Hint — kya tumhe normalization ya scaling ka concept pata hai? 💪
#
#
#
# Normalization ek alag topic hai — zaroor sikhenge!
# Lekin abhi ke liye ek simple approach use karte hain jo beginners ke liye perfect hai:
# diameter_1 > 15mm → 1 point (bada lesion)
# diameter_1 ≤ 15mm → 0 point (chota lesion)
# Kyun 15mm? Kyunki tumhara data yaad hai?
#
#
# Overall average: 11.90
# Biopsed=False average: 10.40
# Biopsed=True average: 12.07
#
# 15mm se bada matlab — average se kaafi zyada bada — suspicious!

# %% [raw]
# Ab Poora Risk Score Formula
# Column                 True           Unknown           False
# grew                   1               0.5               0
# changed                1                 0.5             0
# bleed               1                    0.5               0
# hurt                  1                  0.5                 0
# elevation               1                 0.5                0
# smoke              1                    0.5                0
# cancer_history        1                0.5                   0
# diameter_1 > 15       1                 —                    0
# diameter_2 > 15        1                  —                    0
#
#
# Maximum possible score = 9 points
#
# Risk Categories
# 0 - 3  → Low Risk   🟢
# 3 - 6  → Medium Risk 🟡
# 6 - 9  → High Risk  🔴

# %%
#risk_df = df[df['biopsed']==False].copy()

# Hint — ek column ka example:

#risk_df['score_grew'] = risk_df['grew'].map({
#    True: 1, 
#    False: 0
#})

#Aur Ek Problem Hai
#.map() ek column pe kaam karta hai — multiple columns pe nahi!
#Multiple columns ke liye .replace() use karte hain:

# %%
risk_df = df[df['biopsed']==False].copy()

cols_2 = ['grew' , 'changed', 'bleed', 'hurt', 'elevation', 'smoke' , 'cancer_history']

risk_df[['score_grew' , 'score_changed', 'score_bleed' , 'score_hurt', 'score_elevation' , 'score_smoke', 'score_cancer_history']] = risk_df[cols_2].replace({
    True: 1, 
    False: 0,
    'Unknown':0.5
})

# %% [raw]
# risk_df = df[df['biopsed']==False]  # No copy!
#
# risk_df['score_grew'] = ...
# # ⚠️ WARNING aayega!
# # "SettingWithCopyWarning"
# # Matlab — original df bhi change ho sakta hai!

# %%
risk_df
# Out:
#      patient_id  lesion_id    smoke    drink background_father  \
# 0      PAT_1516       1765  Unknown  Unknown           Unknown
# 2      PAT_1545       1867  Unknown  Unknown           Unknown
# 3      PAT_1989       4061  Unknown  Unknown           Unknown
# 5      PAT_1549       1882  Unknown  Unknown           Unknown
# 8      PAT_1995       4080  Unknown  Unknown           Unknown
# ...         ...        ...      ...      ...               ...
# 2288   PAT_1407       1402  Unknown  Unknown           Unknown
# 2290   PAT_1294       1031  Unknown  Unknown           Unknown
# 2293   PAT_1708       3156  Unknown  Unknown           Unknown
# 2295   PAT_1343       1217  Unknown  Unknown           Unknown
# 2297   PAT_1714       3189  Unknown  Unknown           Unknown
#
#      background_mother  age pesticide   gender skin_cancer_history  ...  \
# 0              Unknown    8   Unknown  Unknown             Unknown  ...
# ...

# %%
# Agar diameter_1 > 15 toh 1, warna 0
#risk_df['score_diameter_1'] = (risk_df['diameter_1'] > 15).astype(int)

# %% [raw]
# # Ab Poora Code
#
# risk_df = df[df['biopsed']==False].copy()
#
# cols_2 = ['grew','changed','bleed',
#           'hurt','elevation','smoke','cancer_history']
#
# # Step 1 — Boolean/Unknown columns
# risk_df[['score_grew','score_changed','score_bleed',
#          'score_hurt','score_elevation','score_smoke',
#          'score_cancer_history']] = risk_df[cols_2].replace({
#     True: 1,
#     False: 0,
#     'Unknown': 0.5
# })
#
# # Step 2 — Diameter columns
# risk_df['score_diameter_1'] = (risk_df['diameter_1'] > 15).astype(int)
# risk_df['score_diameter_2'] = (risk_df['diameter_2'] > 15).astype(int)
#
# # Step 3 — Total risk score
# risk_df['total_risk_score'] = risk_df[[
#     'score_grew','score_changed','score_bleed',
#     'score_hurt','score_elevation','score_smoke',
#     'score_cancer_history','score_diameter_1','score_diameter_2'
# ]].sum(axis=1)  # Hint: saare scores add karne ka method!
#
# # Step 4 — Risk category
# risk_df['risk_category'] = pd.cut(
#     risk_df['total_risk_score'],
#     bins=[0,3,6,9],
#     labels=['Low Risk', 'Medium Risk', 'High Risk']
# )
#
# print(risk_df['risk_category'].value_counts())
#
# TypeError: can only concatenate str (not "float") to str

# %% [raw]
# # Galat ❌
# bins=[0-3, 3-6, 6-9]
# # Python samjhega: bins=[-3, -3, -3] — subtraction!
#
# # Sahi ✅
# bins=[0, 3, 6, 9]
# # Matlab: 0 se 3, 3 se 6, 6 se 9 — teen ranges!
#
#
# # Galat ❌
# ].sum()
# # Yeh har column ka sum karta hai — har row ka nahi!
#
# # Sahi ✅
# ].sum(axis=1)
# # axis=1 matlab — har ROW ke saare scores add karo!
#
#
# .cut() Simple Explanation
#
# pd.cut(score, bins=[0,3,6,9], labels=['Low','Medium','High'])
# Bas itna samjho —
# Score 1.5 → 0 aur 3 ke beech → Low Risk
# Score 4.0 → 3 aur 6 ke beech → Medium Risk
# Score 7.5 → 6 aur 9 ke beech → High Risk
# Automatic category assign karta hai! ✅
#
#
# bins=[0, 3, 6, 9]
# pd.cut mein by default 0 include nahi hota!
# Matlab score = 0 wale patients kisi bhi category mein nahi aate!
# Fix:
# pythonbins=[-0.1, 3, 6, 9]
# # -0.1 isliye taaki 0 score bhi Low Risk mein aaye!

# %%
print(risk_df['grew'].dtype)
print(risk_df['grew'].unique())
print()
print(risk_df['smoke'].dtype)
print(risk_df['smoke'].unique())
# Out:
# str
# <StringArray>
# ['FALSE', 'TRUE']
# Length: 2, dtype: str
#
# object
# ['Unknown' False True]

# %%
# cols_2 ke liye - grew, changed, bleed, hurt, elevation
# Yeh sab STRING hain - 'TRUE'/'FALSE' capital mein
cols_boolean = ['grew','changed','bleed','hurt','elevation']

risk_df[['score_grew','score_changed','score_bleed',
         'score_hurt','score_elevation']] = risk_df[cols_boolean].replace({
    'TRUE': 1,
    'FALSE': 0
})

# smoke aur cancer_history ke liye - mixed type hai
cols_mixed = ['smoke','cancer_history']

risk_df[['score_smoke','score_cancer_history']] = risk_df[cols_mixed].replace({
    True: 1,
    False: 0,
    'Unknown': 0.5
})

# %% [raw]
# Kyun Alag Alag Kiya?
# grew    = 'TRUE' / 'FALSE'  → String
# smoke   = True / False / 'Unknown' → Mixed
# Ek hi replace mein dono handle nahi hote — isliye alag kiya! ✅

# %%
#ab poora code:

risk_df = df[df['biopsed']==False].copy()

# Step 1a — grew, changed, bleed, hurt, elevation
# Yeh STRING hain — 'TRUE'/'FALSE' capital mein
cols_boolean = ['grew','changed','bleed','hurt','elevation']
risk_df[['score_grew','score_changed','score_bleed',
         'score_hurt','score_elevation']] = risk_df[cols_boolean].replace({
    'TRUE': 1,
    'FALSE': 0
})

# Step 1b — smoke aur cancer_history alag!
risk_df['score_smoke'] = risk_df['smoke'].replace({
    True: 1, False: 0, 'Unknown': 0.5
})
risk_df['score_cancer_history'] = risk_df['cancer_history'].replace({
    True: 1, False: 0, 'Unknown': 0.5
})

# Step 2 — Diameter
risk_df['score_diameter_1'] = (risk_df['diameter_1'] > 15).astype(int)
risk_df['score_diameter_2'] = (risk_df['diameter_2'] > 15).astype(int)

# Step 3 — Total score
risk_df['total_risk_score'] = risk_df[[
    'score_grew','score_changed','score_bleed',
    'score_hurt','score_elevation','score_smoke',
    'score_cancer_history','score_diameter_1','score_diameter_2'
]].sum(axis=1)

# Step 4 — Category
risk_df['risk_category'] = pd.cut(
    risk_df['total_risk_score'],
    #bins=[-0.1,3,6,9],
    bins=[-0.1, 2, 3.5, 5.1],
    labels=['Low Risk', 'Medium Risk', 'High Risk']
)

print(risk_df['risk_category'].value_counts())
# Out:
# risk_category
# Low Risk       708
# Medium Risk    224
# High Risk       24
# Name: count, dtype: int64

# %%
risk_df
# Out:
#      patient_id  lesion_id    smoke    drink background_father  \
# 0      PAT_1516       1765  Unknown  Unknown           Unknown
# 2      PAT_1545       1867  Unknown  Unknown           Unknown
# 3      PAT_1989       4061  Unknown  Unknown           Unknown
# 5      PAT_1549       1882  Unknown  Unknown           Unknown
# 8      PAT_1995       4080  Unknown  Unknown           Unknown
# ...         ...        ...      ...      ...               ...
# 2288   PAT_1407       1402  Unknown  Unknown           Unknown
# 2290   PAT_1294       1031  Unknown  Unknown           Unknown
# 2293   PAT_1708       3156  Unknown  Unknown           Unknown
# 2295   PAT_1343       1217  Unknown  Unknown           Unknown
# 2297   PAT_1714       3189  Unknown  Unknown           Unknown
#
#      background_mother  age pesticide   gender skin_cancer_history  ...  \
# 0              Unknown    8   Unknown  Unknown             Unknown  ...
# ...

# %%
# High Risk = 0 suspicious lag raha hai — data se verify karte hain!

#Pehle Check Karo

print("Max risk score:", risk_df['total_risk_score'].max())
print("Min risk score:", risk_df['total_risk_score'].min())
print()
print(risk_df['total_risk_score'].value_counts().sort_index(ascending=False).head(10))
# Out:
# Max risk score: 5.0
# Min risk score: 0
#
# total_risk_score
# 5.0      4
# 4.0     20
# 3.0    224
# 2.0    295
# 1.0    393
# 0       20
# Name: count, dtype: int64

# %% [raw]
# Toh Bins Adjust Karo!
# Maximum score 5.0 hai — toh categories yeh honi chahiye:
# 0 - 2   → Low Risk    🟢
# 2 - 3.5 → Medium Risk 🟡
# 3.5 - 5 → High Risk   🔴
#
# Ek Important Baat Samjho! 🧠
#
# Bins fixed nahi hote — data dekh ke decide karte hain!
#
# Pehle humne socha 0-9 scale hoga — lekin data ne bataya max 5 hai!

# %%
# Hamesha verify karo!
print("Total patients:", len(risk_df))
print("Categorized:", risk_df['risk_category'].value_counts().sum())
# Out:
# Total patients: 956
# Categorized: 956

# %%
# Ab High Risk 24 patients dekhte hain — run karo:

high_risk = risk_df[risk_df['risk_category'] == 'High Risk']
print(high_risk)
print('________________________________________________')
print(high_risk[['patient_id','diagnostic','total_risk_score',
                 'grew','bleed','changed','smoke',
                 'cancer_history','diameter_1']].to_string())
# Out:
#      patient_id  lesion_id    smoke    drink background_father  \
# 34     PAT_1926       3871  Unknown  Unknown           Unknown
# 307    PAT_1682       3050  Unknown  Unknown           Unknown
# 490      PAT_87        133    False    False         POMERANIA
# 640    PAT_2131       4683  Unknown  Unknown           Unknown
# 651      PAT_61        299     True    False             ITALY
# 671    PAT_1914       3823  Unknown  Unknown           Unknown
# 672    PAT_1978       4004  Unknown  Unknown           Unknown
# 899    PAT_2103       4581  Unknown  Unknown           Unknown
# 1017   PAT_1951       3934  Unknown  Unknown           Unknown
# 1242   PAT_1351       1231  Unknown  Unknown           Unknown
# 1278   PAT_1153        555  Unknown  Unknown           Unknown
# 1405   PAT_1129        498  Unknown  Unknown           Unknown
# 1414   PAT_2022       4184  Unknown  Unknown           Unknown
# 1483    PAT_270       1384    False    False         POMERANIA
# ...

# %%
# Ab Ek Zaroori Kaam
# Clean risk data save karo:

risk_df.to_csv('risk_analysis.csv', index=False)
print("Saved!")
# Out:
# Saved!

# %% [raw]
# P I V O T  T A B L E  has started
#
# Pivot Table Ka Matlab Kya Hota Hai?
# Real life example — tumhara ghar ka budget:
# Mahina  | Khana | Rent  | Travel | Total
# --------|-------|-------|--------|------
# January | 5000  | 10000 | 2000   | 17000
# February| 4500  | 10000 | 1500   | 16000
# Yeh ek pivot table hai — grouped summary!

# %%
risk_df
# Out:
#      patient_id  lesion_id    smoke    drink background_father  \
# 0      PAT_1516       1765  Unknown  Unknown           Unknown
# 2      PAT_1545       1867  Unknown  Unknown           Unknown
# 3      PAT_1989       4061  Unknown  Unknown           Unknown
# 5      PAT_1549       1882  Unknown  Unknown           Unknown
# 8      PAT_1995       4080  Unknown  Unknown           Unknown
# ...         ...        ...      ...      ...               ...
# 2288   PAT_1407       1402  Unknown  Unknown           Unknown
# 2290   PAT_1294       1031  Unknown  Unknown           Unknown
# 2293   PAT_1708       3156  Unknown  Unknown           Unknown
# 2295   PAT_1343       1217  Unknown  Unknown           Unknown
# 2297   PAT_1714       3189  Unknown  Unknown           Unknown
#
#      background_mother  age pesticide   gender skin_cancer_history  ...  \
# 0              Unknown    8   Unknown  Unknown             Unknown  ...
# ...

# %% [raw]
# Ab Samjho — Pivot Table Kab Use Karein? 💡
# Jab boss pooche:
#
# "Har X ke liye — har Y ka Z batao"
#
# Har Department ke liye — har City ka Average Salary
# Har Month ke liye      — har Product ki Total Sales
# Har Region ke liye     — har Employee ka Max Bonus
# "Har X — Har Y — Z" = Pivot Table! 🎯
#
#
# Basic Syntax 👇
# pd.pivot_table(
#     data,              # Kaunsa DataFrame?
#     values,            # Kis column ki calculation?
#     index,             # Rows mein kya hoga?
#     columns,           # Columns mein kya hoga?
#     aggfunc            # Kya calculation? mean/sum/count
# )
#
# chaar parts yaad rakho.
# data    → Tumhara DataFrame
# values  → "Z" — Kya calculate karna hai?
# index   → "X" — Rows mein kya hoga?
# columns → "Y" — Columns mein kya hoga?
# aggfunc → Calculation type

# %%
#Pehle Age Groups Banao!
#Tumhare dataset mein age ek continuous number hai — groups mein todna padega!

print(risk_df['age'].describe())
# Out:
# count    956.000000
# mean      57.041841
# std       16.985437
# min        6.000000
# 25%       46.000000
# 50%       59.000000
# 75%       69.000000
# max       92.000000
# Name: age, dtype: float64

# %% [raw]
# # Hint — same tarika!
# risk_df['age_group'] = pd.cut(
#     risk_df['age'],
#     bins=[5,20,40,60],
#     labels=['Children/Young', 'Young Adult', 'Middle Age', 'Senior']
# )
#
# print(risk_df['age_group'].value_counts())
#
# ValueError: Bin labels must be one fewer than the number of bin edges

# %%
# Hint — same tarika!
risk_df['age_group'] = pd.cut(
    risk_df['age'],
    bins=[5,20,40,60,92],
    labels=['Children/Young', 'Young Adult', 'Middle Age', 'Senior']
)

print(risk_df['age_group'].value_counts())
# Out:
# age_group
# Senior            440
# Middle Age        351
# Young Adult       133
# Children/Young     32
# Name: count, dtype: int64

# %% [raw]
# Error Kya Bol Raha Hai
# Bins    = [5, 20, 40, 60]     → 4 numbers = 3 ranges
# Labels  = 4 labels            → Mismatch!
# Dekho visually:
# 5 -------- 20 -------- 40 -------- 60
#   Children    Young Adult   Middle Age
# Sirf 3 ranges bani — lekin tumne 4 labels diye!
#
# Yaad Karo — Option B Kya Tha
# 0-20   → Children/Young
# 21-40  → Young Adult
# 41-60  → Middle Age
# 61-92  → Senior        ← Yeh missing hai bins mein!
# 92 (max age) bins mein add karna bhool gaye!

# %% [raw]
# Pehle percentage samjhate hain — real life se! 😊
#
# Percentage Ka Simple Formula
#
# Percentage = (Jo chahiye / Total) × 100
#
#
# Real Life Example — Tumhara Hi!
# Senior     = 440
# Total      = 956
#
# Senior %   = (440 / 956) × 100
#            = 0.460 × 100
#            = 46%
# Bas itna! 😊
#
# Pivot Table Mein Bhi Same Logic
# NEV High Risk  =   9
# NEV Total      = 184
#
# High Risk %    = (9 / 184) × 100
#                = 4.89%

# %%
pivot1 = pd.pivot_table(
    risk_df,              # Kaunsa DataFrame?
    values  = 'total_risk_score',   # Z — risk score count karna hai
    index   = 'diagnostic', # X — Rows mein Diagnostic
    columns = 'risk_category',      # Y — Columns mein risk_category
    aggfunc = 'count'       # count nikalna hai         # Kya calculation? mean/sum/count
)

print(pivot1)
# Out:
# risk_category  Low Risk  Medium Risk  High Risk
# diagnostic
# ACK                 499           47          6
# NEV                  75          100          9
# SEK                 134           77          9

# %% [raw]
# Ek interesting cheez dikh rahi hai —
# NEV — jo normal mole hai — usmein Medium Risk 100 hai!
# Kya yeh surprising nahi? Normal mole mein itna medium risk kyun? 🤔
# Baad mein discuss karenge — pehle percentage column add karo!
#
# Percentage Column — Khud Socho!
# Percentage matlab:
# High Risk % = High Risk / Total * 100
# Toh pehle Total column chahiye!

# %%
# Step 1 — Total column add karo
pivot1['Total'] = pivot1['Low Risk'] + pivot1['Medium Risk'] + pivot1['High Risk']

# %%
print(pivot1)
# Out:
# risk_category  Low Risk  Medium Risk  High Risk  Total
# diagnostic
# ACK                 499           47          6    552
# NEV                  75          100          9    184
# SEK                 134           77          9    220

# %%
# Step 2 — High Risk % add karo
pivot1['High Risk %'] = (
    pivot1['High Risk'] / pivot1['Total'] * 100
).round(2)

print(pivot1)
# Out:
# risk_category  Low Risk  Medium Risk  High Risk  Total  High Risk %
# diagnostic
# ACK                 499           47          6    552         1.09
# NEV                  75          100          9    184         4.89
# SEK                 134           77          9    220         4.09

# %% [raw]
# NEV — normal mole — mein High Risk % sabse zyada kyun hai?
# Yeh surprising hai — doctor ke liye important insight hai!
# Socho aur jawab do — phir Pivot 2 banayenge! 💪
#
# NEV Ka Nature Kya Hai?
# NEV = Normal Mole — benign hai abhi!
# Lekin socho —
#
# Kya ek normal mole kabhi kabhi cancer mein badal sakta hai?
#
# Real life mein —
# Normal mole → Time ke saath → Grow kiya
#                              → Color badla
#                              → Bleed kiya
#                              → Elevated hua
#                              ⬇️
#              Ab yeh suspicious lag raha hai!
#              Doctor ko lagta hai — biopsy karni chahiye!
#
#
# Matlab Yeh Hai
# NEV wale patients mein jo Medium aur High Risk hain —
# Yeh woh patients hain jinke normal mole ne alarming signs dikhane shuru kar diye!
# Yeh doctor ke liye sabse important insight hai:
#
# "NEV patients ko ignore mat karo — unhe regularly monitor karo!"

# %%
risk_df
# Out:
#      patient_id  lesion_id    smoke    drink background_father  \
# 0      PAT_1516       1765  Unknown  Unknown           Unknown
# 2      PAT_1545       1867  Unknown  Unknown           Unknown
# 3      PAT_1989       4061  Unknown  Unknown           Unknown
# 5      PAT_1549       1882  Unknown  Unknown           Unknown
# 8      PAT_1995       4080  Unknown  Unknown           Unknown
# ...         ...        ...      ...      ...               ...
# 2288   PAT_1407       1402  Unknown  Unknown           Unknown
# 2290   PAT_1294       1031  Unknown  Unknown           Unknown
# 2293   PAT_1708       3156  Unknown  Unknown           Unknown
# 2295   PAT_1343       1217  Unknown  Unknown           Unknown
# 2297   PAT_1714       3189  Unknown  Unknown           Unknown
#
#      background_mother  age pesticide   gender skin_cancer_history  ...  \
# 0              Unknown    8   Unknown  Unknown             Unknown  ...
# ...

# %%
#🎯 Ab Pivot 2 Banao!
#Age group wise — same tarika — khud likho!  ismei fill_value = 0 nahi likhu toh jab first time code run hua hoga toh Nan aaya tha ACK aur SEC ke total mei.

pivot2 = pd.pivot_table(
    risk_df,
    values = 'total_risk_score',
    index  = 'diagnostic',
    columns= 'age_group',
    aggfunc= 'count'
)

pivot2['Total'] =  pivot2['Senior'] + pivot2['Middle Age'] + pivot2['Young Adult'] + pivot2['Children/Young']
pivot2['High Risk %'] = (pivot2['Senior'] / pivot2['Total']  * 100).round(2)

print(pivot2)
# Out:
# age_group   Children/Young  Young Adult  Middle Age  Senior  Total  \
# diagnostic
# ACK                    NaN         35.0       237.0   280.0    NaN
# NEV                   32.0         91.0        54.0     7.0  184.0
# SEK                    NaN          7.0        60.0   153.0    NaN
#
# age_group   High Risk %
# diagnostic
# ACK                 NaN
# NEV                 3.8
# SEK                 NaN

# %% [raw]
# Mistake 1 — NaN kyun aa raha hai Total mein?
# ACK aur SEK ka Total = NaN!
#
# ACK ka Children/Young = NaN hai!
# NaN + koi bhi number = NaN! ❌
# Isliye ACK aur SEK ka Total NaN aa gaya!
#
#
# pehle ek doubt clear karo.
# ACK ka `Children/Young` = NaN hai!   iska matlab children/young ka ek bhi value ACK nahi hai diagnostic column mei?
#
# Yahi Matlab Hai!
# ACK + Children/Young = NaN
# Matlab — dataset mein ek bhi bachcha nahi hai jiska diagnostic ACK hai!
#
# Real Life Mein Kyun?
# ACK = Actinic Keratosis = Sun damage se hota hai!
# Bachcha  → Kam saalon ki dhoop → ACK nahi
# Senior   → 60+ saal ki dhoop  → ACK zyada!
# Isliye ACK mein:
#
# Children/Young = NaN ✅ — Logical hai!
# Senior = 280 ✅ — Sabse zyada! Logical hai!

# %%
#Data se verify karo — assume nahi karte!

ack_children = risk_df[
    (risk_df['diagnostic'] == 'ACK') & 
    (risk_df['age_group'] == 'Children/Young')
]

print("Count:", len(ack_children))
# Out:
# Count: 0

# %%
pivot2 = pd.pivot_table(
    risk_df,
    values = 'total_risk_score',
    index  = 'diagnostic',
    columns= 'age_group',
    aggfunc= 'count',
    fill_value=0
)

pivot2['Total'] =  pivot2['Senior'] + pivot2['Middle Age'] + pivot2['Young Adult'] + pivot2['Children/Young']
# pivot2['High Risk %'] = (pivot2['Senior'] / pivot2['Total']  * 100).round(2)

#pivot2['Senior %'] = (pivot2['Senior'] / pivot2['Total'] * 100).round(2)

# kyunki middle age mei cancer zyada detect hota hai
pivot2['Middle Age %'] = (pivot2['Middle Age'] / pivot2['Total'] * 100).round(2)

print(pivot2)
# Out:
# age_group   Children/Young  Young Adult  Middle Age  Senior  Total  \
# diagnostic
# ACK                      0           35         237     280    552
# NEV                     32           91          54       7    184
# SEK                      0            7          60     153    220
#
# age_group   Middle Age %
# diagnostic
# ACK                42.93
# NEV                29.35
# SEK                27.27

# %% [raw]
# Lekin Abhi Bhi Ek Mistake Hai!
# Yeh line dekho:
# pythonpivot2['High Risk %'] = (pivot2['Senior'] / pivot2['Total'] * 100).round(2)
# Yeh Senior % calculate kar raha hai — High Risk % nahi! ❌
#
# Socho — Pivot2 Ka Structure Kya Hai?
# age_group    Children  Young Adult  Middle Age  Senior  Total
# diagnostic
# ACK               0         35         237       280    552
# NEV              32         91          54         7    184
# SEK               0          7          60       153    220
# Columns mein age groups hain — High Risk column hai hi nahi yahan!
#
# Toh High Risk % Kaise Nikalein? 🤔
# Pivot2 ka purpose alag hai —
#
# Yahan hum dekhna chahte hain — kaunse age group mein zyada patients hain?
#
# Toh percentage bhi age group ka hona chahiye!
# For example:
# ACK mein Senior % = 280/552 * 100 = 50.7%
# Toh column ka naam bhi badlo:
#
# pivot2['Senior %'] = (pivot2['Senior'] / pivot2['Total'] * 100).round(2)

# %% [raw]
# ab right hai kya , ya phir koi meaningful data nahi nikla?
#
# 2:24 AM
# PERFECT! 🎯✅ Bilkul sahi hai!
#
# Data Kya Bol Raha Hai — Padho!
# ACK Middle Age % = 42.93%
# NEV Middle Age % = 29.35%
# SEK Middle Age % = 27.27%
# ACK sabse zyada Middle Age mein hai — 42.93%!
#
# Real life meaning:
#
# "Pre-cancerous condition ACK — middle age (41-60) mein sabse zyada detect hoti hai!"
#
# Yeh cousin ke liye valuable insight hai! ✅
#
# 🏆 Dono Pivots Ready!
# Pivot 1 → Diagnostic wise risk categories + High Risk %
# Pivot 2 → Diagnostic wise age groups + Middle Age %

# %%
with pd.ExcelWriter('skin_cancer_analysis.xlsx') as writer:
    pivot1.to_excel(writer, sheet_name='Risk by Diagnostic')
    pivot2.to_excel(writer, sheet_name='Age Group Analysis')
    risk_df.to_excel(writer, sheet_name='Full Risk Data', index=False)

print("Excel file saved!")
# Out:
# Excel file saved!

# %% [raw]
# Sirf Ek Task Bacha! 🎯
# Cousin ne kaha tha:
#
# "Heatmap on patients data to highlight people with high risk"
#
# Heatmap matlab — colors se data dikhana!
# Jaise:
# High Risk  → 🔴 Red
# Medium Risk → 🟡 Yellow
# Low Risk   → 🟢 Green

# %%
risk_df.columns
# Out:
# Index(['patient_id', 'lesion_id', 'smoke', 'drink', 'background_father',
#        'background_mother', 'age', 'pesticide', 'gender',
#        'skin_cancer_history', 'cancer_history', 'has_piped_water',
#        'has_sewage_system', 'fitspatrick', 'region', 'diameter_1',
#        'diameter_2', 'diagnostic', 'itch', 'grew', 'hurt', 'changed', 'bleed',
#        'elevation', 'img_id', 'biopsed', 'score_grew', 'score_changed',
#        'score_bleed', 'score_hurt', 'score_elevation', 'score_smoke',
#        'score_cancer_history', 'score_diameter_1', 'score_diameter_2',
#        'total_risk_score', 'risk_category', 'age_group'],
#       dtype='str')

# %% [raw]
# Ek Sawaal Pehle Socho 🤔
# Heatmap mein kaunse columns dikhane chahiye?
#
# Doctor ke liye sabse useful heatmap kaisa hoga?
#
# Toh Final Decision
# Teenon groups rakhenge — lekin smart tarike se!
# Group 1 — Patient Info     → Kaun hai?
# Group 2 — Risk Summary     → Kitna risk hai?
# Group 3 — Risk Factors     → Kyun risk hai?

# %%
#Pehle columns select kiya hu:

heatmap_df = risk_df[[
    # Group 1 — Patient Info
    'patient_id', 'diagnostic', 'age_group',
    # Group 2 — Risk Summary
    'total_risk_score', 'risk_category',
    # Group 3 — Risk Factors
    'grew', 'changed', 'bleed', 'hurt', 'elevation',
    'smoke', 'cancer_history', 'diameter_1', 'diameter_2'
]].sort_values('total_risk_score', ascending=False)

#print(heatmap_df)  # 956 rows

#risk_df mein pehle se sirf biopsed=False wale hain!
#Aur heatmap_df bana hai risk_df se — toh automatically sirf False wale hain! ✅

# %%
# Step 1 — Columns select karo aur score ke hisaab se sort karo
heatmap_df = risk_df[[
    'patient_id', 'diagnostic', 'age_group',
    'total_risk_score', 'risk_category',
    'grew', 'changed', 'bleed', 'hurt', 'elevation',
    'smoke', 'cancer_history', 'diameter_1', 'diameter_2'
]].sort_values('total_risk_score', ascending=False)

# Step 2 — Color function banao
def color_risk(val):
    if val == 'High Risk':
        return 'background-color: Red'
    elif val == 'Medium Risk':
        return 'background-color: Yellow'
    else:
        return 'background-color: Green'

# Step 3 — Styled object banao
styled = heatmap_df.style

# Step 4 — risk_category column mein color lagao
styled = styled.map(
    color_risk,
    subset=['risk_category']
)

# Step 5 — total_risk_score mein gradient color lagao
styled = styled.background_gradient(
    subset=['total_risk_score'],
    cmap='RdYlGn_r'
)

# Step 6 — Excel mein save karo
styled.to_excel(
    'skin_cancer_heatmap.xlsx',
    engine='openpyxl',
    index=False
)

print("Heatmap Excel saved!")

#Newer Pandas mein applymap ka naam badal gaya hai — map ho gaya!
# Out:
# Heatmap Excel saved!

# %% [raw]
# Ab Box Plot Sikhte Hain! 📊
# Pehle samjho — Box Plot kya hota hai?
# Real life example socho —
# Tumhare class mein 10 students ke marks hain:
#
# 2, 5, 8, 8, 9, 10, 10, 11, 15, 50
#
# Agar average nikalo — 12.8 aayega!
# Lekin 50 ek student ne liya — jo bahut alag hai baaki se!
# Average se poori picture nahi milti — Box Plot se milti hai!
#
# Box Plot 5 Cheezein Dikhata Hai
# Minimum  → Sabse kam value
# Q1       → 25% data yahan tak
# Median   → Beech ki value
# Q3       → 75% data yahan tak
# Maximum  → Sabse zyada value
#
# Tumse Pehla Sawaal
# Tumhare dataset mein kaunse columns ka box plot banana meaningful hoga?
# Hint — box plot numbers ke liye hota hai — categories ke liye nahi!
# Tumhare paas kaunse numerical columns hain? 🤔
